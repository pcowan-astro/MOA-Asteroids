# %%
#-----------------------------------------------------------------------------------------------------------------
# Script to create custom classification models HybridA described in
# Towards Asteroid Detection in Microlensing Surveys with Deep Learning by Cowan et al.
#-----------------------------------------------------------------------------------------------------------------
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Input, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, add
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.constraints import max_norm

# %%
# Directory paths

# Each data directory is expected to contain 2 directories: 
#  "Yes" containing tracklet images and 
#  "No" containing no-tracklet images

TRAIN_DIR = r"/path_to_training_set/"
VALID_DIR = r"/path_to_validation_set/"
TEST_DIR = r"/path_to_test_set/"

# Path to weight
WEIGHTS_DIR = r"/path_to_weights/"

# %%
# Model parameters
epochs = 50
batch_size = 32
image_size = 128  
image_shape = (image_size,image_size,3)

# Loading the data in a compatible format and standardizing values to lie between 0 & 1
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    batch_size=batch_size,
    target_size=(image_size, image_size),
    class_mode='binary')

valid_generator = valid_datagen.flow_from_directory(
    VALID_DIR,
    batch_size=batch_size,
    target_size=(image_size, image_size),
    class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    batch_size=batch_size,
    target_size=(image_size, image_size),
    class_mode='binary',
    shuffle=False)

# %%
def hybrid_module(layer_in, f1, bname):
    merge_input = layer_in
    
    # adding identity layer
    if layer_in.shape[-1] != f1:
        merge_input = Conv2D(f1, (1,1), padding='same', activation='relu', kernel_constraint=max_norm(3), bias_constraint=max_norm(3), name=("identity_" + bname))(layer_in)
    
    # 1x1 conv
    conv1 = Conv2D(f1, (1,1), padding='same', activation='relu', kernel_constraint=max_norm(3), bias_constraint=max_norm(3), name="hybrid_1_"+bname)(layer_in)
    
    # 3x3 conv
    conv3 = Conv2D(f1, (1,1), padding='same', activation='relu', kernel_constraint=max_norm(3), bias_constraint=max_norm(3), name="hybrid_3in_"+bname)(layer_in)
    conv3 = Conv2D(f1, (3,3), padding='same', activation='relu', kernel_constraint=max_norm(3), bias_constraint=max_norm(3), name="hybrid_3out_"+bname)(conv3)
    
    # 5x5 conv replaced with 2 3x3
    conv5 = Conv2D(f1, (1,1), padding='same', activation='relu', kernel_constraint=max_norm(3), bias_constraint=max_norm(3), name="hybrid_5in_"+bname)(layer_in)
    conv5 = Conv2D(f1, (3,3), padding='same', activation='relu', kernel_constraint=max_norm(3), bias_constraint=max_norm(3), name="hybrid_5a_out_"+bname)(conv5)
    conv5 = Conv2D(f1, (3,3), padding='same', activation='relu', kernel_constraint=max_norm(3), bias_constraint=max_norm(3), name="hybrid_5b_out_"+bname)(conv5)

    # add filters, assumes filters/channels last
    layer_out = add([conv1, conv3, conv5, merge_input])
    
    # activation function
    layer_out = Activation('relu')(layer_out)
    
    return layer_out

# %%
# define model input
visible = Input(shape=image_shape, name="input")

# Layer 1
layer0 = Conv2D(32, (3, 3), activation='relu', kernel_constraint=max_norm(3), bias_constraint=max_norm(3), name="conv1")(visible)
layer0 = BatchNormalization(name="norm1")(layer0)
layer0 = MaxPooling2D(pool_size=(2, 2), name="maxpool1")(layer0)

# hybrid block 1
layer = hybrid_module(layer0, 32, "b1")

# hybrid block 2
layer = hybrid_module(layer, 64, "b2")
layer = MaxPooling2D(pool_size=(2, 2), name="maxpool_b2")(layer)

# hybrid block 3
layer = hybrid_module(layer, 96, "b3")

# hybrid block 4
layer = hybrid_module(layer, 128, "b4")
layer = MaxPooling2D(pool_size=(2, 2), name="maxpool_b4")(layer)

# hybrid block 5
layer = hybrid_module(layer, 160,"b5")

# hybrid block 6
layer = hybrid_module(layer, 192, "b6")
layer = MaxPooling2D(pool_size=(2, 2), name="maxpool_b6")(layer)

# hybrid block 7
layer = hybrid_module(layer, 224, "b7")

# hybrid block 8
layer = hybrid_module(layer, 256, "b8")

# Output layers
avgPool = GlobalAveragePooling2D()(layer)

flatten = Flatten(name="flatten")(avgPool)

output = Dense(128, activation='relu', name="fc1")(flatten)
output = Dropout(0.4)(output)
output = Dense(1, activation='sigmoid', name="output")(output)

# create model
model = Model(inputs=visible, outputs=output, name="HybridA")

# summarize model
model.summary()
# Out:
# Model: "HybridA"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 126, 126, 32) 896         input[0][0]
# __________________________________________________________________________________________________
# norm1 (BatchNormalization)      (None, 126, 126, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 63, 63, 32)   0           norm1[0][0]
# __________________________________________________________________________________________________
# hybrid_5in_b1 (Conv2D)          (None, 63, 63, 32)   1056        maxpool1[0][0]
# __________________________________________________________________________________________________
# hybrid_3in_b1 (Conv2D)          (None, 63, 63, 32)   1056        maxpool1[0][0]
# __________________________________________________________________________________________________
# hybrid_5a_out_b1 (Conv2D)       (None, 63, 63, 32)   9248        hybrid_5in_b1[0][0]
# __________________________________________________________________________________________________
# hybrid_1_b1 (Conv2D)            (None, 63, 63, 32)   1056        maxpool1[0][0]
# __________________________________________________________________________________________________
# hybrid_3out_b1 (Conv2D)         (None, 63, 63, 32)   9248        hybrid_3in_b1[0][0]
# __________________________________________________________________________________________________
# hybrid_5b_out_b1 (Conv2D)       (None, 63, 63, 32)   9248        hybrid_5a_out_b1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 63, 63, 32)   0           hybrid_1_b1[0][0]
#                                                                  hybrid_3out_b1[0][0]
#                                                                  hybrid_5b_out_b1[0][0]
#                                                                  maxpool1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 63, 63, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# hybrid_5in_b2 (Conv2D)          (None, 63, 63, 64)   2112        activation[0][0]
# __________________________________________________________________________________________________
# hybrid_3in_b2 (Conv2D)          (None, 63, 63, 64)   2112        activation[0][0]
# __________________________________________________________________________________________________
# hybrid_5a_out_b2 (Conv2D)       (None, 63, 63, 64)   36928       hybrid_5in_b2[0][0]
# __________________________________________________________________________________________________
# hybrid_1_b2 (Conv2D)            (None, 63, 63, 64)   2112        activation[0][0]
# __________________________________________________________________________________________________
# hybrid_3out_b2 (Conv2D)         (None, 63, 63, 64)   36928       hybrid_3in_b2[0][0]
# __________________________________________________________________________________________________
# hybrid_5b_out_b2 (Conv2D)       (None, 63, 63, 64)   36928       hybrid_5a_out_b2[0][0]
# __________________________________________________________________________________________________
# identity_b2 (Conv2D)            (None, 63, 63, 64)   2112        activation[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 63, 63, 64)   0           hybrid_1_b2[0][0]
#                                                                  hybrid_3out_b2[0][0]
#                                                                  hybrid_5b_out_b2[0][0]
#                                                                  identity_b2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 63, 63, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# maxpool_b2 (MaxPooling2D)       (None, 31, 31, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# hybrid_5in_b3 (Conv2D)          (None, 31, 31, 96)   6240        maxpool_b2[0][0]
# __________________________________________________________________________________________________
# hybrid_3in_b3 (Conv2D)          (None, 31, 31, 96)   6240        maxpool_b2[0][0]
# __________________________________________________________________________________________________
# hybrid_5a_out_b3 (Conv2D)       (None, 31, 31, 96)   83040       hybrid_5in_b3[0][0]
# __________________________________________________________________________________________________
# hybrid_1_b3 (Conv2D)            (None, 31, 31, 96)   6240        maxpool_b2[0][0]
# __________________________________________________________________________________________________
# hybrid_3out_b3 (Conv2D)         (None, 31, 31, 96)   83040       hybrid_3in_b3[0][0]
# __________________________________________________________________________________________________
# hybrid_5b_out_b3 (Conv2D)       (None, 31, 31, 96)   83040       hybrid_5a_out_b3[0][0]
# __________________________________________________________________________________________________
# identity_b3 (Conv2D)            (None, 31, 31, 96)   6240        maxpool_b2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 31, 31, 96)   0           hybrid_1_b3[0][0]
#                                                                  hybrid_3out_b3[0][0]
#                                                                  hybrid_5b_out_b3[0][0]
#                                                                  identity_b3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 31, 31, 96)   0           add_2[0][0]
# __________________________________________________________________________________________________
# hybrid_5in_b4 (Conv2D)          (None, 31, 31, 128)  12416       activation_2[0][0]
# __________________________________________________________________________________________________
# hybrid_3in_b4 (Conv2D)          (None, 31, 31, 128)  12416       activation_2[0][0]
# __________________________________________________________________________________________________
# hybrid_5a_out_b4 (Conv2D)       (None, 31, 31, 128)  147584      hybrid_5in_b4[0][0]
# __________________________________________________________________________________________________
# hybrid_1_b4 (Conv2D)            (None, 31, 31, 128)  12416       activation_2[0][0]
# __________________________________________________________________________________________________
# hybrid_3out_b4 (Conv2D)         (None, 31, 31, 128)  147584      hybrid_3in_b4[0][0]
# __________________________________________________________________________________________________
# hybrid_5b_out_b4 (Conv2D)       (None, 31, 31, 128)  147584      hybrid_5a_out_b4[0][0]
# __________________________________________________________________________________________________
# identity_b4 (Conv2D)            (None, 31, 31, 128)  12416       activation_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 31, 31, 128)  0           hybrid_1_b4[0][0]
#                                                                  hybrid_3out_b4[0][0]
#                                                                  hybrid_5b_out_b4[0][0]
#                                                                  identity_b4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 31, 31, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# maxpool_b4 (MaxPooling2D)       (None, 15, 15, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# hybrid_5in_b5 (Conv2D)          (None, 15, 15, 160)  20640       maxpool_b4[0][0]
# __________________________________________________________________________________________________
# hybrid_3in_b5 (Conv2D)          (None, 15, 15, 160)  20640       maxpool_b4[0][0]
# __________________________________________________________________________________________________
# hybrid_5a_out_b5 (Conv2D)       (None, 15, 15, 160)  230560      hybrid_5in_b5[0][0]
# __________________________________________________________________________________________________
# hybrid_1_b5 (Conv2D)            (None, 15, 15, 160)  20640       maxpool_b4[0][0]
# __________________________________________________________________________________________________
# hybrid_3out_b5 (Conv2D)         (None, 15, 15, 160)  230560      hybrid_3in_b5[0][0]
# __________________________________________________________________________________________________
# hybrid_5b_out_b5 (Conv2D)       (None, 15, 15, 160)  230560      hybrid_5a_out_b5[0][0]
# __________________________________________________________________________________________________
# identity_b5 (Conv2D)            (None, 15, 15, 160)  20640       maxpool_b4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 15, 15, 160)  0           hybrid_1_b5[0][0]
#                                                                  hybrid_3out_b5[0][0]
#                                                                  hybrid_5b_out_b5[0][0]
#                                                                  identity_b5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 15, 15, 160)  0           add_4[0][0]
# __________________________________________________________________________________________________
# hybrid_5in_b6 (Conv2D)          (None, 15, 15, 192)  30912       activation_4[0][0]
# __________________________________________________________________________________________________
# hybrid_3in_b6 (Conv2D)          (None, 15, 15, 192)  30912       activation_4[0][0]
# __________________________________________________________________________________________________
# hybrid_5a_out_b6 (Conv2D)       (None, 15, 15, 192)  331968      hybrid_5in_b6[0][0]
# __________________________________________________________________________________________________
# hybrid_1_b6 (Conv2D)            (None, 15, 15, 192)  30912       activation_4[0][0]
# __________________________________________________________________________________________________
# hybrid_3out_b6 (Conv2D)         (None, 15, 15, 192)  331968      hybrid_3in_b6[0][0]
# __________________________________________________________________________________________________
# hybrid_5b_out_b6 (Conv2D)       (None, 15, 15, 192)  331968      hybrid_5a_out_b6[0][0]
# __________________________________________________________________________________________________
# identity_b6 (Conv2D)            (None, 15, 15, 192)  30912       activation_4[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 15, 15, 192)  0           hybrid_1_b6[0][0]
#                                                                  hybrid_3out_b6[0][0]
#                                                                  hybrid_5b_out_b6[0][0]
#                                                                  identity_b6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 15, 15, 192)  0           add_5[0][0]
# __________________________________________________________________________________________________
# maxpool_b6 (MaxPooling2D)       (None, 7, 7, 192)    0           activation_5[0][0]
# __________________________________________________________________________________________________
# hybrid_5in_b7 (Conv2D)          (None, 7, 7, 224)    43232       maxpool_b6[0][0]
# __________________________________________________________________________________________________
# hybrid_3in_b7 (Conv2D)          (None, 7, 7, 224)    43232       maxpool_b6[0][0]
# __________________________________________________________________________________________________
# hybrid_5a_out_b7 (Conv2D)       (None, 7, 7, 224)    451808      hybrid_5in_b7[0][0]
# __________________________________________________________________________________________________
# hybrid_1_b7 (Conv2D)            (None, 7, 7, 224)    43232       maxpool_b6[0][0]
# __________________________________________________________________________________________________
# hybrid_3out_b7 (Conv2D)         (None, 7, 7, 224)    451808      hybrid_3in_b7[0][0]
# __________________________________________________________________________________________________
# hybrid_5b_out_b7 (Conv2D)       (None, 7, 7, 224)    451808      hybrid_5a_out_b7[0][0]
# __________________________________________________________________________________________________
# identity_b7 (Conv2D)            (None, 7, 7, 224)    43232       maxpool_b6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 224)    0           hybrid_1_b7[0][0]
#                                                                  hybrid_3out_b7[0][0]
#                                                                  hybrid_5b_out_b7[0][0]
#                                                                  identity_b7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, 7, 224)    0           add_6[0][0]
# __________________________________________________________________________________________________
# hybrid_5in_b8 (Conv2D)          (None, 7, 7, 256)    57600       activation_6[0][0]
# __________________________________________________________________________________________________
# hybrid_3in_b8 (Conv2D)          (None, 7, 7, 256)    57600       activation_6[0][0]
# __________________________________________________________________________________________________
# hybrid_5a_out_b8 (Conv2D)       (None, 7, 7, 256)    590080      hybrid_5in_b8[0][0]
# __________________________________________________________________________________________________
# hybrid_1_b8 (Conv2D)            (None, 7, 7, 256)    57600       activation_6[0][0]
# __________________________________________________________________________________________________
# hybrid_3out_b8 (Conv2D)         (None, 7, 7, 256)    590080      hybrid_3in_b8[0][0]
# __________________________________________________________________________________________________
# hybrid_5b_out_b8 (Conv2D)       (None, 7, 7, 256)    590080      hybrid_5a_out_b8[0][0]
# __________________________________________________________________________________________________
# identity_b8 (Conv2D)            (None, 7, 7, 256)    57600       activation_6[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 256)    0           hybrid_1_b8[0][0]
#                                                                  hybrid_3out_b8[0][0]
#                                                                  hybrid_5b_out_b8[0][0]
#                                                                  identity_b8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, 7, 256)    0           add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           activation_7[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# fc1 (Dense)                     (None, 128)          32896       flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           fc1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            129         dropout[0][0]
# ==================================================================================================
# Total params: 6,373,473
# Trainable params: 6,373,409
# Non-trainable params: 64
# __________________________________________________________________________________________________

# %%
# Load weights
model.build(input_shape = (1, 128, 128, 3))
model.load_weights(WEIGHTS_DIR) 

# Compile model (required to make predictions)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Evaluate
model.evaluate(test_generator)
# Out:
# 75/75 [==============================] - 8s 79ms/step - loss: 0.6178 - accuracy: 0.9514
# [0.6899896860122681, 0.9546789526939392]
